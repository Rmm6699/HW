# %% [markdown]
# <a href="https://colab.research.google.com/github/Rmm6699/HW/blob/master/SinoPac_Final_student.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Download data and load as panda dataframe

# %% [markdown]
# ## Download data

# %%
# !wget -q -O "2890_stockinfo.csv" "https://docs.google.com/uc?export=download&id=1Qal8gF--2sL8M5DKJQMe6E9jsaHFcvTi"

# %%
import pandas as pd
stock_no = '2890'
stock_data = pd.read_csv('/content/2890_stockinfo.csv',index_col=[0], parse_dates=[0], dayfirst=True, usecols=[i for i in range(1,11)])
stock_data
# Out:
#             stock_id  Trading_Volume  Trading_money   open    max    min  \
# date
# 2008-01-02      2890        12748820      153857198  12.25  12.25  11.85
# 2008-01-03      2890        11841342      139093030  11.70  11.90  11.60
# 2008-01-04      2890        19647612      237797162  11.80  12.35  11.70
# 2008-01-07      2890        13445931      163369158  12.15  12.30  12.05
# 2008-01-08      2890        10755517      131890117  12.10  12.40  12.10
# ...              ...             ...            ...    ...    ...    ...
# 2022-10-03      2890        18146749      307800394  17.10  17.20  16.85
# 2022-10-04      2890        16596464      281035891  17.00  17.10  16.80
# 2022-10-05      2890        14186412      240887722  17.00  17.10  16.90
# 2022-10-06      2890        15359185      262594491  17.00  17.25  16.90
# 2022-10-07      2890         9089952      154274954  17.00  17.05  16.90
#
#             close  spread  Trading_turnover
# date
# 2008-01-02  11.85   -0.30              1315
# 2008-01-03  11.85    0.00              1350
# 2008-01-04  12.35    0.50              2303
# 2008-01-07  12.05   -0.30              1261
# 2008-01-08  12.30    0.25              1386
# ...           ...     ...               ...
# 2022-10-03  16.85   -0.45              5373
# 2022-10-04  16.95    0.10              3779
# 2022-10-05  16.95    0.00              3013
# 2022-10-06  17.15    0.20              3562
# 2022-10-07  16.95   -0.20              3278
#
# [3641 rows x 9 columns]

# %% [markdown]
# ## (Optional) Download data using FinMind API (Advanced topic)

# %%
# !pip -q install FinMind
# Out:
#      |████████████████████████████████| 48 kB 3.4 MB/s
#      |████████████████████████████████| 135 kB 15.5 MB/s
#      |████████████████████████████████| 101 kB 4.0 MB/s
#      |████████████████████████████████| 298 kB 50.8 MB/s
#      |████████████████████████████████| 793 kB 44.6 MB/s
#      |████████████████████████████████| 58 kB 5.5 MB/s
#      |████████████████████████████████| 96 kB 4.8 MB/s
#      |████████████████████████████████| 133 kB 44.3 MB/s
#      |████████████████████████████████| 232 kB 53.3 MB/s
#      |████████████████████████████████| 1.6 MB 43.9 MB/s
#      |████████████████████████████████| 130 kB 52.5 MB/s
#   Building wheel for ta (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires ipython~=7.9.0, but you have ipython 7.34.0 which is incompatible.

# %%
from FinMind.data import DataLoader
stock_no = '2890'
dl = DataLoader()
stock_data = dl.taiwan_stock_daily(stock_id=stock_no, start_date='2008-01-01')
stock_data.set_index('date',inplace=True)
stock_data
# Out:
#            stock_id  Trading_Volume  Trading_money   open    max    min  \
# date
# 2008-01-02     2890        12748820      153857198  12.25  12.25  11.85
# 2008-01-03     2890        11841342      139093030  11.70  11.90  11.60
# 2008-01-04     2890        19647612      237797162  11.80  12.35  11.70
# 2008-01-07     2890        13445931      163369158  12.15  12.30  12.05
# 2008-01-08     2890        10755517      131890117  12.10  12.40  12.10
# ...             ...             ...            ...    ...    ...    ...
# 2022-10-05     2890        14186412      240887722  17.00  17.10  16.90
# 2022-10-06     2890        15359185      262594491  17.00  17.25  16.90
# 2022-10-07     2890         9089952      154274954  17.00  17.05  16.90
# 2022-10-11     2890        22152876      374183621  16.85  17.05  16.70
# 2022-10-12     2890        14876964      254194924  16.95  17.25  16.85
#
#             close  spread  Trading_turnover
# date
# 2008-01-02  11.85   -0.30              1315
# 2008-01-03  11.85    0.00              1350
# 2008-01-04  12.35    0.50              2303
# 2008-01-07  12.05   -0.30              1261
# 2008-01-08  12.30    0.25              1386
# ...           ...     ...               ...
# 2022-10-05  16.95    0.00              3013
# 2022-10-06  17.15    0.20              3562
# 2022-10-07  16.95   -0.20              3278
# 2022-10-11  16.85   -0.10              6079
# 2022-10-12  17.10    0.25              3746
#
# [3643 rows x 9 columns]

# %% [markdown]
# # Data Cleaning

# %%
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline
stock_data = stock_data[['close']].loc['2016-01-01':'2017-12-31'].dropna()
stock_data.plot(title=f"Closing price for {stock_no}", figsize=(20,4), legend=None)

# %%
stock_data_train = stock_data[:stock_data.size-30]
stock_data_test = stock_data[stock_data.size-30:stock_data.size]

# %% [markdown]
# # Predicting closing price with ARIMA

# %%
# !pip -q uninstall statsmodels -y
# !pip -q install statsmodels 
# !pip -q install pmdarima
# Out:
#      |████████████████████████████████| 9.8 MB 7.4 MB/s
#      |████████████████████████████████| 1.8 MB 28.9 MB/s

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima_process import arma_generate_sample
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error

# %%
acf = plot_acf(stock_data_train, lags = 50)
pacf = plot_pacf(stock_data_train, lags = 50)

# %%
stock_data_train_diff = stock_data_train.diff().dropna()
diff_acf1 = plot_acf(stock_data_train_diff, lags = 50)
diff_pacf1 = plot_acf(stock_data_train_diff, lags = 50)

# %% [markdown]
# **Please Determine the order of ARIMA**

# %%
ARMA_model = ARIMA(stock_data_train, order=[6,0,6]) #Please find the best order of ARIMA
ARMA_model_fit = ARMA_model.fit()
print(ARMA_model_fit.summary())
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  close   No. Observations:                  460
# Model:                 ARIMA(6, 0, 6)   Log Likelihood                 427.078
# Date:                Thu, 13 Oct 2022   AIC                           -826.155
# Time:                        06:49:21   BIC                           -768.318
# Sample:                             0   HQIC                          -803.380
#                                 - 460
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          9.3393      0.092    101.257      0.000       9.159       9.520
# ar.L1          0.8044      0.242      3.328      0.001       0.331       1.278
# ar.L2          0.3861      0.207      1.866      0.062      -0.019       0.792
# ar.L3         -0.5877      0.231     -2.545      0.011      -1.040      -0.135
# ar.L4          0.3545      0.202      1.753      0.080      -0.042       0.751
# ar.L5          0.6943      0.158      4.404      0.000       0.385       1.003
# ar.L6         -0.6892      0.167     -4.118      0.000      -1.017      -0.361
# ma.L1          0.1904      0.247      0.772      0.440      -0.293       0.674
# ma.L2         -0.2132      0.280     -0.762      0.446      -0.762       0.336
# ma.L3          0.3152      0.216      1.459      0.144      -0.108       0.738
# ma.L4          0.0903      0.206      0.438      0.661      -0.314       0.494
# ma.L5         -0.6882      0.213     -3.236      0.001      -1.105      -0.271
# ma.L6         -0.0146      0.066     -0.221      0.825      -0.144       0.115
# sigma2         0.0091      0.000     24.254      0.000       0.008       0.010
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.04   Jarque-Bera (JB):              6065.33
# Prob(Q):                              0.84   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.21   Skew:                            -1.83
# Prob(H) (two-sided):                  0.00   Kurtosis:                        20.41
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
pred_start = stock_data.size - 29
pred_end = stock_data.size
ARMA_predictions = ARMA_model_fit.predict(start=pred_start, end=pred_end)
plt.figure(figsize=(20,5))
plt.plot(stock_data['close'].values)
plt.plot(ARMA_predictions)
plt.legend(('Data', 'Predictions'), fontsize=16)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:843: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   data=self.data,

# %%
ARMA_pred_mse = mean_squared_error(stock_data_test.values, ARMA_predictions)
ARMA_pred_rmse= np.sqrt(ARMA_pred_mse)
print("ARMA MSE  : ", ARMA_pred_mse)
print('ARMA RMSE : ', ARMA_pred_rmse)
# Out:
# ARMA MSE  :  0.031085989215355377
# ARMA RMSE :  0.17631219247503951

# %% [markdown]
# # Predicting closing price with Support Vector Regression

# %%
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error

# %%
SVR_stock_data = stock_data.reset_index(drop=True)
train_data = SVR_stock_data.iloc[:449].values.flatten()
test_data = SVR_stock_data.iloc[449:].values.flatten()

def to_sequences(dataset, seq_size=1):
    x = []
    y = []

    for i in range(len(dataset)-seq_size-1):
        #print(i)
        window = dataset[i:(i+seq_size)]
        x.append(window)
        y.append(dataset[i+seq_size])
        
    return np.array(x),np.array(y)

seq_size = 10
trainX, trainY = to_sequences(train_data, seq_size)
testX, testY = to_sequences(test_data, seq_size)
print(trainX.shape, testX.shape)
# Out:
# (438, 10) (30, 10)

# %% [markdown]
# **Please determine the best kernel and regularization term**

# %%
#SVR
svr_rbf = SVR(kernel='rbf', C=1000) #Please determine the best kernel and regularization term
svr_rbf.fit(trainX, trainY)
svr_rbf_confidence = svr_rbf.score(testX, testY)
print('svr_rbf accuracy (Confidence): ' , svr_rbf_confidence)

trainPredict = svr_rbf.predict(trainX)
testPredict = svr_rbf.predict(testX)
# Out:
# svr_rbf accuracy (Confidence):  0.7607435946420018

# %%
#Training MSE
train_pred_mse = mean_squared_error(trainY, trainPredict)
print("train pred MSE  : ", train_pred_mse)
#Training RMSE
train_pred_rmse = np.sqrt(train_pred_mse)
print("train pred RMSE : ", train_pred_rmse)

print("------------------------------------------")
#Testing MSE
SVR_pred_mse = mean_squared_error(testY, testPredict)
print("test pred MSE   : ", SVR_pred_mse)
#Testing RMSE
SVR_pred_rmse = np.sqrt(SVR_pred_mse)
print("test pred RMSE  : ", SVR_pred_rmse)
# Out:
# train pred MSE  :  0.005299221248113068
# train pred RMSE :  0.07279575020640332
# ------------------------------------------
# test pred MSE   :  0.0034363599980218027
# test pred RMSE  :  0.05862047422208219

# %%
plt.figure(figsize=(10,4))
plt.plot(trainY)
plt.plot(trainPredict)
plt.legend(('Train Data', 'Predictions'), fontsize=16)

plt.figure(figsize=(10,4))
plt.plot(testY)
plt.plot(testPredict)
plt.legend(('Test Data', 'Predictions'), fontsize=16)

# %% [markdown]
# # Predicting closing price with Simple NN

# %%
from keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
NN_stock_data = stock_data.reset_index(drop=True)

data_df = pd.DataFrame(NN_stock_data)
scaler = MinMaxScaler()
scaler.fit(data_df)
NN_stock_data = scaler.transform(NN_stock_data)

train_data = NN_stock_data[:449]
test_data = NN_stock_data[449:]

# %%
def to_sequences(dataset, seq_size=1):
    x = []
    y = []

    for i in range(len(dataset)-seq_size-1):
        #print(i)
        window = dataset[i:(i+seq_size), 0]
        x.append(window)
        y.append(dataset[i+seq_size, 0])
        
    return np.array(x),np.array(y)

seq_size = 20
#Train and Test data
trainX, trainY = to_sequences(train_data, seq_size)
testX, testY = to_sequences(test_data, seq_size)

# %% [markdown]
# **Please design a good model to predice the closing price**

# %%
model_stock = Sequential()
model_stock.add(Dense(64, input_dim=seq_size, activation='relu')) 
model_stock.add(Dense(32, activation='relu'))  
model_stock.add(Dense(1))
model_stock.compile(loss='mean_squared_error', optimizer='adam', metrics = ['mse'])
print(model_stock.summary())
model_stock.fit(trainX, trainY, validation_split=0.1, verbose=1, epochs=20)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                1344
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 3,457
# Trainable params: 3,457
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/20
# 13/13 [==============================] - 1s 19ms/step - loss: 0.0236 - mse: 0.0236 - val_loss: 0.0092 - val_mse: 0.0092
# Epoch 2/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 3/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 4/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 5/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 6/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 7/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 8/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 9/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 10/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 11/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 12/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 13/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 14/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 15/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 16/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 17/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 18/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 19/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 20/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0021 - val_mse: 0.0021

# %%
losses = pd.DataFrame(model_stock.history.history)
losses.plot(figsize=(12,4))

# %%
# make predictions
trainPredict = model_stock.predict(trainX)
testPredict = model_stock.predict(testX)

# Estimate model performance
#SInce we used minmaxscaler we can now use scaler.inverse_transform
#to invert the transformation.

trainPredict = scaler.inverse_transform(trainPredict)
trainY_inverse = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY_inverse = scaler.inverse_transform([testY])

#Training MSE
train_pred_mse = mean_squared_error(trainY_inverse[0], trainPredict[:,0])
print("train pred MSE: ", train_pred_mse)
#Training RMSE
train_pred_rmse = np.sqrt(train_pred_mse)
print("train pred RMSE: ", train_pred_rmse)

#Testing MSE
NN_pred_mse = mean_squared_error(testY_inverse[0], testPredict[:,0])
print("test pred MSE: ", NN_pred_mse)
#Testing RMSE
NN_pred_rmse = np.sqrt(NN_pred_mse)
print("test pred RMSE: ", NN_pred_rmse)
# Out:
# 14/14 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 19ms/step
# train pred MSE:  0.01418380612713189
# train pred RMSE:  0.11909578551372794
# test pred MSE:  0.007556218461029812
# test pred RMSE:  0.08692651184207159

# %%
#Plot Training Data and Predictions
plt.figure(figsize=(10,4))
plt.plot(trainY_inverse[0])
plt.plot(trainPredict[:,0])
plt.legend(('Train Data', 'Predictions'), fontsize=16)

#Plot Data and Predictions
plt.figure(figsize=(10,4))
plt.plot(testY_inverse[0])
plt.plot(testPredict[:,0])
plt.legend(('Test Data', 'Predictions'), fontsize=16)

# %% [markdown]
# # Predicting closing price with RNN

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import SimpleRNN
from keras.layers import LSTM
from keras.layers import GRU
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
NN_stock_data = stock_data.reset_index(drop=True)

data_df = pd.DataFrame(NN_stock_data)
scaler = MinMaxScaler()
scaler.fit(data_df)
NN_stock_data = scaler.transform(NN_stock_data)

train_data = NN_stock_data[:449]
test_data = NN_stock_data[449:]

# %%
def to_sequences(dataset, seq_size=1):
    x = []
    y = []

    for i in range(len(dataset)-seq_size-1):
        #print(i)
        window = dataset[i:(i+seq_size), 0]
        x.append(window)
        y.append(dataset[i+seq_size, 0])
        
    return np.array(x),np.array(y)

seq_size = 20
#Train and Test data
trainX, trainY = to_sequences(train_data, seq_size)
testX, testY = to_sequences(test_data, seq_size)
trainX = np.reshape(trainX, (-1, seq_size, 1))
testX = np.reshape(testX, (-1, seq_size, 1))

# %% [markdown]
# **Please design a good model to predict the closing price**

# %%
model_stock = Sequential()
model_stock.add(SimpleRNN(units=30, input_shape=(trainX.shape[1], 1)))  
model_stock.add(Dense(1))
model_stock.compile(loss='mean_squared_error', optimizer='adam', metrics = ['mse'])
print(model_stock.summary())
model_stock.fit(trainX, trainY, validation_split=0.1,
          verbose=1, epochs=100)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 30)                960
#
#  dense_3 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 991
# Trainable params: 991
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 13/13 [==============================] - 1s 26ms/step - loss: 0.1053 - mse: 0.1053 - val_loss: 0.0160 - val_mse: 0.0160
# Epoch 2/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0094 - mse: 0.0094 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 3/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 4/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 5/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 6/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 7/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 8/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 9/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 10/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0031 - val_mse: 0.0031
# Epoch 11/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0031 - val_mse: 0.0031
# Epoch 12/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 13/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 14/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 15/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 16/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 17/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 18/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 19/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 20/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 21/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 22/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 23/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 24/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 25/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 26/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 27/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 28/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 29/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 30/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 31/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 32/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 33/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 34/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 35/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 36/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 37/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 38/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 39/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 40/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 41/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 42/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 43/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 44/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 45/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 46/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 47/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 48/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 49/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 50/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 51/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 52/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 53/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 54/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 55/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 56/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 57/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 58/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 59/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 60/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 61/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 62/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 63/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 64/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 65/100
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 66/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 67/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 68/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 69/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 70/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 71/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 72/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 73/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 74/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 75/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 76/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 77/100
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 78/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 79/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 80/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 81/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 82/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 83/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 84/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 85/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 86/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 87/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 88/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 89/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 90/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 91/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 92/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 93/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 94/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 95/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 96/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 97/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 98/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 99/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 100/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0013 - val_mse: 0.0013

# %%
losses = pd.DataFrame(model_stock.history.history)
losses.plot(figsize=(12,4))

# %%
# make predictions
trainPredict = model_stock.predict(trainX)
testPredict = model_stock.predict(testX)

# Estimate model performance
#SInce we used minmaxscaler we can now use scaler.inverse_transform
#to invert the transformation.

trainPredict = scaler.inverse_transform(trainPredict)
trainY_inverse = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY_inverse = scaler.inverse_transform([testY])

#Training MSE
train_pred_mse = mean_squared_error(trainY_inverse[0], trainPredict[:,0])
print("train pred MSE: ", train_pred_mse)
#Training RMSE
train_pred_rmse = np.sqrt(train_pred_mse)
print("train pred RMSE: ", train_pred_rmse)

#Testing MSE
RNN_pred_mse = mean_squared_error(testY_inverse[0], testPredict[:,0])
print("test pred MSE: ", RNN_pred_mse)
#Testing RMSE
RNN_pred_rmse = np.sqrt(RNN_pred_mse)
print("test pred RMSE: ", RNN_pred_rmse)
# Out:
# 14/14 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 21ms/step
# train pred MSE:  0.009087873147222425
# train pred RMSE:  0.09533033697214348
# test pred MSE:  0.005366690804750713
# test pred RMSE:  0.07325770133406256

# %%
#Plot Training Data and Predictions
plt.figure(figsize=(10,4))
plt.plot(trainY_inverse[0])
plt.plot(trainPredict[:,0])
plt.legend(('Train Data', 'Predictions'), fontsize=16)

#Plot Data and Predictions
plt.figure(figsize=(10,4))
plt.plot(testY_inverse[0])
plt.plot(testPredict[:,0])
plt.legend(('Test Data', 'Predictions'), fontsize=16)

# %% [markdown]
# # Predicting closing price with LSTM

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import SimpleRNN
from keras.layers import LSTM
from keras.layers import GRU
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
NN_stock_data = stock_data.reset_index(drop=True)

data_df = pd.DataFrame(NN_stock_data)
scaler = MinMaxScaler()
scaler.fit(data_df)
NN_stock_data = scaler.transform(NN_stock_data)

train_data = NN_stock_data[:449]
test_data = NN_stock_data[449:]

# %%
def to_sequences(dataset, seq_size=1):
    x = []
    y = []

    for i in range(len(dataset)-seq_size-1):
        #print(i)
        window = dataset[i:(i+seq_size), 0]
        x.append(window)
        y.append(dataset[i+seq_size, 0])
        
    return np.array(x),np.array(y)

seq_size = 20
#Train and Test data
trainX, trainY = to_sequences(train_data, seq_size)
testX, testY = to_sequences(test_data, seq_size)
trainX = np.reshape(trainX, (-1, seq_size, 1))
testX = np.reshape(testX, (-1, seq_size, 1))

# %% [markdown]
# **Please design a good model to predict the closing price**

# %%
model_stock = Sequential()
model_stock.add(LSTM(units=30, input_shape=(trainX.shape[1], 1)))  
model_stock.add(Dense(1))
model_stock.compile(loss='mean_squared_error', optimizer='adam', metrics = ['mse'])
print(model_stock.summary())
model_stock.fit(trainX, trainY, validation_split=0.1,
          verbose=1, epochs=100)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 30)                3840
#
#  dense_4 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 3,871
# Trainable params: 3,871
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 13/13 [==============================] - 3s 60ms/step - loss: 0.0826 - mse: 0.0826 - val_loss: 0.0066 - val_mse: 0.0066
# Epoch 2/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0095 - mse: 0.0095 - val_loss: 0.0091 - val_mse: 0.0091
# Epoch 3/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 4/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 5/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 6/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 7/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 8/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 9/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 10/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 11/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 12/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 13/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 14/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 15/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 16/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 17/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 18/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 19/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 20/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 21/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 22/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 23/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 24/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0031 - val_mse: 0.0031
# Epoch 25/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 26/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 27/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 28/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 29/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 30/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 31/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 32/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 33/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 34/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 35/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 36/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 37/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 38/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 39/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 40/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 41/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 42/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 43/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 44/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 45/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 46/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 47/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 48/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 49/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 50/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 51/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 52/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 53/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 54/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 55/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 56/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 57/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 58/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 59/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 60/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 61/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 62/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 63/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 64/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 65/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 66/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 67/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 68/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 69/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 70/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 71/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 72/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 73/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 74/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 75/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 76/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 77/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 78/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 79/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 80/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 81/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 82/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 83/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 84/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 85/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 86/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 87/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 88/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 89/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 90/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 91/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 92/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 93/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 94/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 95/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 96/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 97/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 98/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 99/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 100/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0019 - val_mse: 0.0019

# %%
losses = pd.DataFrame(model_stock.history.history)
losses.plot(figsize=(12,4))

# %%
# make predictions
trainPredict = model_stock.predict(trainX)
testPredict = model_stock.predict(testX)

# Estimate model performance
#SInce we used minmaxscaler we can now use scaler.inverse_transform
#to invert the transformation.

trainPredict = scaler.inverse_transform(trainPredict)
trainY_inverse = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY_inverse = scaler.inverse_transform([testY])

#Training MSE
train_pred_mse = mean_squared_error(trainY_inverse[0], trainPredict[:,0])
print("train pred MSE: ", train_pred_mse)
#Training RMSE
train_pred_rmse = np.sqrt(train_pred_mse)
print("train pred RMSE: ", train_pred_rmse)

#Testing MSE
LSTM_pred_mse = mean_squared_error(testY_inverse[0], testPredict[:,0])
print("test pred MSE: ", LSTM_pred_mse)
#Testing RMSE
LSTM_pred_rmse = np.sqrt(LSTM_pred_mse)
print("test pred RMSE: ", LSTM_pred_rmse)
# Out:
# 14/14 [==============================] - 1s 4ms/step
# 1/1 [==============================] - 0s 24ms/step
# train pred MSE:  0.012696446461262003
# train pred RMSE:  0.11267850931416337
# test pred MSE:  0.004893744200844542
# test pred RMSE:  0.06995530144917211

# %%
#Plot Training Data and Predictions
plt.figure(figsize=(10,4))
plt.plot(trainY_inverse[0])
plt.plot(trainPredict[:,0])
plt.legend(('Train Data', 'Predictions'), fontsize=16)

#Plot Data and Predictions
plt.figure(figsize=(10,4))
plt.plot(testY_inverse[0])
plt.plot(testPredict[:,0])
plt.legend(('Test Data', 'Predictions'), fontsize=16)

# %% [markdown]
# # Predicting closing price with GRU

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import SimpleRNN
from keras.layers import LSTM
from keras.layers import GRU
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
NN_stock_data = stock_data.reset_index(drop=True)

data_df = pd.DataFrame(NN_stock_data)
scaler = MinMaxScaler()
scaler.fit(data_df)
NN_stock_data = scaler.transform(NN_stock_data)

train_data = NN_stock_data[:449]
test_data = NN_stock_data[449:]

# %%
def to_sequences(dataset, seq_size=1):
    x = []
    y = []

    for i in range(len(dataset)-seq_size-1):
        #print(i)
        window = dataset[i:(i+seq_size), 0]
        x.append(window)
        y.append(dataset[i+seq_size, 0])
        
    return np.array(x),np.array(y)

seq_size = 20
#Train and Test data
trainX, trainY = to_sequences(train_data, seq_size)
testX, testY = to_sequences(test_data, seq_size)
trainX = np.reshape(trainX, (-1, seq_size, 1))
testX = np.reshape(testX, (-1, seq_size, 1))

# %% [markdown]
# **Please design a good model to predict the closing price**

# %%
model_stock = Sequential()
model_stock.add(GRU(units=30, input_shape=(trainX.shape[1], 1)))  
model_stock.add(Dense(1))
model_stock.compile(loss='mean_squared_error', optimizer='adam', metrics = ['mse'])
print(model_stock.summary())
model_stock.fit(trainX, trainY, validation_split=0.1,
          verbose=1, epochs=100)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 30)                2970
#
#  dense_5 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 3,001
# Trainable params: 3,001
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 13/13 [==============================] - 3s 57ms/step - loss: 0.1824 - mse: 0.1824 - val_loss: 0.0507 - val_mse: 0.0507
# Epoch 2/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0235 - mse: 0.0235 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 3/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0087 - val_mse: 0.0087
# Epoch 4/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 5/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 6/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 7/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 8/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 9/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 10/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0031 - val_mse: 0.0031
# Epoch 11/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 12/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 13/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 14/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 15/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 16/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 17/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 18/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 19/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 20/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 21/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 22/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 23/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 24/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 25/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 26/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 27/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 28/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 29/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 30/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 31/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 32/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 33/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 34/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 35/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 36/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 37/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 38/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 39/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 40/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 41/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 42/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 43/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 44/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 45/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 46/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 47/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 48/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 49/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 50/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 51/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 52/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 53/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 54/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 55/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 56/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 57/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 58/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 59/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 60/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 61/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 62/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 63/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 64/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 65/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 66/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 67/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 68/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 69/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 70/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 71/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 72/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 73/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 74/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 75/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 76/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 77/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 78/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 79/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 80/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 81/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 82/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 83/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 84/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 85/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 86/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 87/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 88/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 89/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 90/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 91/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 92/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 93/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 94/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 95/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 96/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 97/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 98/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 99/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 100/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0013 - val_mse: 0.0013

# %%
losses = pd.DataFrame(model_stock.history.history)
losses.plot(figsize=(12,4))

# %%
# make predictions
trainPredict = model_stock.predict(trainX)
testPredict = model_stock.predict(testX)

# Estimate model performance
#SInce we used minmaxscaler we can now use scaler.inverse_transform
#to invert the transformation.

trainPredict = scaler.inverse_transform(trainPredict)
trainY_inverse = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY_inverse = scaler.inverse_transform([testY])

#Training MSE
train_pred_mse = mean_squared_error(trainY_inverse[0], trainPredict[:,0])
print("train pred MSE: ", train_pred_mse)
#Training RMSE
train_pred_rmse = np.sqrt(train_pred_mse)
print("train pred RMSE: ", train_pred_rmse)

#Testing MSE
GRU_pred_mse = mean_squared_error(testY_inverse[0], testPredict[:,0])
print("test pred MSE: ", GRU_pred_mse)
#Testing RMSE
GRU_pred_rmse = np.sqrt(GRU_pred_mse)
print("test pred RMSE: ", GRU_pred_rmse)
# Out:
# 14/14 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 19ms/step
# train pred MSE:  0.008892176205629614
# train pred RMSE:  0.09429833617635898
# test pred MSE:  0.004191999843453184
# test pred RMSE:  0.06474565501601774

# %%
#Plot Training Data and Predictions
plt.figure(figsize=(10,4))
plt.plot(trainY_inverse[0])
plt.plot(trainPredict[:,0])
plt.legend(('Train Data', 'Predictions'), fontsize=16)

#Plot Data and Predictions
plt.figure(figsize=(10,4))
plt.plot(testY_inverse[0])
plt.plot(testPredict[:,0])
plt.legend(('Test Data', 'Predictions'), fontsize=16)

# %% [markdown]
# # (Optional) Try to predict other stock closing price (Advanced topic)

# %% [markdown]
# # Final Result Comparison

# %%
print("ARMA mse: ", ARMA_pred_mse)
print("ARMA rmse: ", ARMA_pred_rmse)
print("==============================")
print("SVR mse: ", SVR_pred_mse)
print("SVR rmse: ", SVR_pred_rmse)
print("==============================")
print("NN mse: ", NN_pred_mse)
print("NN rmse: ", NN_pred_rmse)
print("==============================")
print("RNN mse: ", RNN_pred_mse)
print("RNN rmse: ", RNN_pred_rmse)
print("==============================")
print("LSTM mse: ", LSTM_pred_mse)
print("LSTM rmse: ", LSTM_pred_rmse)
print("==============================")
print("GRU mse: ", GRU_pred_mse)
print("GRU rmse: ", GRU_pred_rmse)
best_model = []
best_performance = min(ARMA_pred_rmse, SVR_pred_rmse, RNN_pred_rmse, LSTM_pred_rmse, GRU_pred_rmse)
if ARMA_pred_rmse == best_performance:
  best_model.append("ARMA")
if SVR_pred_rmse == best_performance:
  best_model.append("SVR")
if NN_pred_rmse == best_performance:
  best_model.append("NN")
if RNN_pred_rmse == best_performance:
  best_model.append("RNN")
if LSTM_pred_rmse == best_performance:
  best_model.append("LSTM")
if GRU_pred_rmse == best_performance:
  best_model.append("GRU")
print("==============================")
print("The best model is", best_model)
# Out:
# ARMA mse:  0.031085989215355377
# ARMA rmse:  0.17631219247503951
# ==============================
# SVR mse:  0.0034363599980218027
# SVR rmse:  0.05862047422208219
# ==============================
# NN mse:  0.007556218461029812
# NN rmse:  0.08692651184207159
# ==============================
# RNN mse:  0.005366690804750713
# RNN rmse:  0.07325770133406256
# ==============================
# LSTM mse:  0.004893744200844542
# LSTM rmse:  0.06995530144917211
# ==============================
# GRU mse:  0.004191999843453184
# GRU rmse:  0.06474565501601774
# ==============================
# The best model is ['SVR']
